# %%
import pandas as pd
import os

# %%
os.listdir("./data/")[0]
# Out:
# '아파트(매매)__실거래가_20220423023515.csv'

# %%
pd.read_csv("./data/" + os.listdir("./data/")[0], encoding="euc-kr", skiprows=15)
# skiprows 는 그 지점 전까지는 skip하고 그 지점 줄 부터 읽어라는 뜻
# Out:
#                 시군구    번지    본번  부번      단지명  전용면적(㎡)    계약년월  계약일 거래금액(만원)  \
# 0       강원도 강릉시 견소동   202  0202   0     송정한신  116.175  202101   14   22,300
# 1       강원도 강릉시 견소동   202  0202   0     송정한신   59.800  202101   15   15,700
# 2       강원도 강릉시 견소동   202  0202   0     송정한신   84.945  202101   19   17,700
# 3       강원도 강릉시 견소동   202  0202   0     송정한신   84.945  202101   19   17,400
# 4       강원도 강릉시 견소동   202  0202   0     송정한신   84.945  202101   19   18,250
# ...             ...   ...   ...  ..      ...      ...     ...  ...      ...
# 62599  충청북도 충주시 호암동  1191  1191   0  호암힐데스하임   84.950  202101    6   37,400
# 62600  충청북도 충주시 호암동  1191  1191   0  호암힐데스하임   84.940  202101   16   42,000
# 62601  충청북도 충주시 호암동  1191  1191   0  호암힐데스하임   84.960  202101   18   37,400
# 62602  충청북도 충주시 호암동  1191  1191   0  호암힐데스하임   84.960  202101   23   38,400
# 62603  충청북도 충주시 호암동  1191  1191   0  호암힐데스하임   84.940  202101   28   42,900
#
#         층  건축년도          도로명     해제사유발생일 거래유형 중개사소재지
# ...

# %%
os.listdir("./data/")
# Out:
# ['아파트(매매)__실거래가_20220423023515.csv',
#  '아파트(매매)__실거래가_20220423023721.csv',
#  '아파트(매매)__실거래가_20220423023753.csv',
#  '아파트(매매)__실거래가_20220423024009.csv',
#  '아파트(매매)__실거래가_20220423024111.csv',
#  '아파트(매매)__실거래가_20220423024238.csv',
#  '아파트(매매)__실거래가_20220423024306.csv',
#  '아파트(매매)__실거래가_20220423024412.csv',
#  '아파트(매매)__실거래가_20220423024438.csv',
#  '아파트(매매)__실거래가_20220423024625.csv',
#  '아파트(매매)__실거래가_20220423024650.csv',
#  '아파트(매매)__실거래가_20220423024724.csv']

# %%
folders= os.listdir("./data/")

# %%
cd ./data
# Out:
# D:\20220103_lab\14.python\project\exercise\2. apt\data

# %%
total2_1_12 = []
for x in range(12):
    df2 = pd.read_csv("../data/apt/" + os.listdir("../data/apt")[x], encoding='euc-kr', skiprows=15, thousands=',')
    total2_1_12.append(df2)

# %%
df_all_apt = pd.DataFrame() 
for files in folders: 
    df= pd.read_csv(files, encoding='euc-kr', skiprows=15, thousands=',') 
    df_all_apt = pd.concat([df_all_apt, df])

# %%
df_all_apt
# Out:
#                 시군구      번지    본번    부번         단지명   전용면적(㎡)    계약년월  계약일  \
# 0       강원도 강릉시 견소동     202  0202   0.0        송정한신  116.1750  202101   14
# 1       강원도 강릉시 견소동     202  0202   0.0        송정한신   59.8000  202101   15
# 2       강원도 강릉시 견소동     202  0202   0.0        송정한신   84.9450  202101   19
# 3       강원도 강릉시 견소동     202  0202   0.0        송정한신   84.9450  202101   19
# 4       강원도 강릉시 견소동     202  0202   0.0        송정한신   84.9450  202101   19
# ...             ...     ...   ...   ...         ...       ...     ...  ...
# 25356  충청북도 충주시 호암동  558-16  0558  16.0          한양   59.8400  202112    7
# 25357  충청북도 충주시 호암동     905  0905   0.0       호암동수채   84.9289  202112    8
# 25358  충청북도 충주시 호암동  221-23  0221  23.0  호암리버빌(1단지)   84.6800  202112    3
# 25359  충청북도 충주시 호암동  221-23  0221  23.0  호암리버빌(1단지)   84.6800  202112    6
# 25360  충청북도 충주시 호암동  221-23  0221  23.0  호암리버빌(1단지)   84.6800  202112   19
#
#        거래금액(만원)   층    건축년도          도로명  해제사유발생일  거래유형  중개사소재지
# ...

# %% [markdown]
# ## 1) 2021년 각 지역별 가장 비싼 아파트?

# %%
df_sort = df_all_apt.sort_values(by=['시군구', '단지명', '계약년월','거래금액(만원)'])

# %%
df_all_apt[['시군구', '단지명', '계약년월','거래금액(만원)']].groupby(['시군구']).max().head()
# Out:
#                       단지명    계약년월 거래금액(만원)
# 시군구
# 강원도 강릉시 견소동  송정해변신도브래뉴아파트  202112    9,200
# 강원도 강릉시 교동          현대하이빌  202112    9,800
# 강원도 강릉시 금학동          금학상가  202111   18,500
# 강원도 강릉시 남문동        삼익그린맨션  202110   24,500
# 강원도 강릉시 내곡동        석미모닝파크  202112    9,900

# %%
df_all_apt[df_all_apt['시군구']== '강원도 강릉시 견소동']['거래금액(만원)'].max()
# Out:
# '9,200'

# %%
df_all_apt[['시군구', '단지명', '계약년월','거래금액(만원)']].groupby(['시군구']).max()
# Out:
#                        단지명    계약년월 거래금액(만원)
# 시군구
# 강원도 강릉시 견소동   송정해변신도브래뉴아파트  202112    9,200
# 강원도 강릉시 교동           현대하이빌  202112    9,800
# 강원도 강릉시 금학동           금학상가  202111   18,500
# 강원도 강릉시 남문동         삼익그린맨션  202110   24,500
# 강원도 강릉시 내곡동         석미모닝파크  202112    9,900
# ...                    ...     ...      ...
# 충청북도 충주시 지현동          지현현대  202111   15,000
# 충청북도 충주시 충의동            현대  202108    7,500
# 충청북도 충주시 칠금동         코오롱동신  202112    9,900
# 충청북도 충주시 풍동           신한강변  202112    4,800
# 충청북도 충주시 호암동       호암힐데스하임  202112    9,900
#
# [3434 rows x 3 columns]

# %% [markdown]
# df_all_apt['시군구'].drop_duplicates()

# %% [markdown]
# ## 2) 강남구 월별 평균 매매가격 추이
# * 그래프로 시각화

# %% [markdown]
# df_all_apt[['시군구', '단지명', '계약년월','거래금액(만원)']].groupby(['시군구'] == '강남').max().head()

# %%
df_all_apt[['시군구', '계약년월', '거래금액(만원)']]
# Out:
#                 시군구    계약년월  거래금액(만원)
# 0       강원도 강릉시 견소동  202101     22300
# 1       강원도 강릉시 견소동  202101     15700
# 2       강원도 강릉시 견소동  202101     17700
# 3       강원도 강릉시 견소동  202101     17400
# 4       강원도 강릉시 견소동  202101     18250
# ...             ...     ...       ...
# 25356  충청북도 충주시 호암동  202112      8000
# 25357  충청북도 충주시 호암동  202112     26800
# 25358  충청북도 충주시 호암동  202112     21700
# 25359  충청북도 충주시 호암동  202112     20700
# 25360  충청북도 충주시 호암동  202112     19700
#
# [603734 rows x 3 columns]

# %%
df_all_apt.groupby('시군구').sum()
# Out:
#                   부번     전용면적(㎡)       계약년월    계약일  거래금액(만원)     층       건축년도  \
# 시군구
# 강원도 강릉시 견소동      0.0  12113.9350   33549508   2784   3735720  1362   332270.0
# 강원도 강릉시 교동     862.0  35304.0702   93372883   7779  11007650  3505   923449.0
# 강원도 강릉시 금학동      5.0     84.6800     202111     19     18500    10     1992.0
# 강원도 강릉시 남문동     16.0   1015.5910    1616833    116    159900    47    15939.0
# 강원도 강릉시 내곡동     50.0  11202.8850   40623329   3316   2251570  1059   400590.0
# ...              ...         ...        ...    ...       ...   ...        ...
# 충청북도 충주시 지현동     0.0   1175.4600    2829479    163    181470   121    27860.0
# 충청북도 충주시 충의동     0.0    209.9900     606315     43     18000    12     5946.0
# 충청북도 충주시 칠금동     0.0  27781.0880   85491002   6874   5744659  3391   844408.0
# 충청북도 충주시 풍동    246.0    892.5200    4648467    396     82150   136    45981.0
# 충청북도 충주시 호암동  3560.0  61008.2415  197054543  16187  11966956  5668  1946216.0
#
#                   해제사유발생일
# ...

# %%
apt_g = df_all_apt[df_all_apt['시군구'].apply(lambda x : x[:9]) == '서울특별시 강남구']

# %%
apt_g
# Out:
#                  시군구      번지    본번    부번         단지명   전용면적(㎡)    계약년월  계약일  \
# 39687  서울특별시 강남구 개포동    1282  1282   0.0   개포래미안포레스트   74.6600  202101   17
# 39688  서울특별시 강남구 개포동     652  0652   0.0      개포우성3차  104.4300  202101    5
# 39689  서울특별시 강남구 개포동     652  0652   0.0      개포우성3차  104.4300  202101    5
# 39690  서울특별시 강남구 개포동     652  0652   0.0      개포우성3차  104.4300  202101   11
# 39691  서울특별시 강남구 개포동     652  0652   0.0      개포우성3차  104.4300  202101   25
# ...              ...     ...   ...   ...         ...       ...     ...  ...
# 15606  서울특별시 강남구 청담동     134  0134   0.0    래미안청담로이뷰  110.2000  202112   23
# 15607  서울특별시 강남구 청담동      10  0010   0.0   삼환아파트101동  114.9700  202112    8
# 15608  서울특별시 강남구 청담동  122-35  0122  35.0  청담신원아침도시마인   27.7131  202112   18
# 15609  서울특별시 강남구 청담동  134-38  0134  38.0        청담자이   89.3560  202112   27
# 15610  서울특별시 강남구 청담동  102-13  0102  13.0   청담파라곤Ⅱ2단지  149.7400  202112   20
#
# ...

# %%
apt_g = apt_g.reset_index()

# %%
apt_g
# Out:
#                  시군구      번지    본번    부번         단지명   전용면적(㎡)    계약년월  계약일  \
# 39687  서울특별시 강남구 개포동    1282  1282   0.0   개포래미안포레스트   74.6600  202101   17
# 39688  서울특별시 강남구 개포동     652  0652   0.0      개포우성3차  104.4300  202101    5
# 39689  서울특별시 강남구 개포동     652  0652   0.0      개포우성3차  104.4300  202101    5
# 39690  서울특별시 강남구 개포동     652  0652   0.0      개포우성3차  104.4300  202101   11
# 39691  서울특별시 강남구 개포동     652  0652   0.0      개포우성3차  104.4300  202101   25
# ...              ...     ...   ...   ...         ...       ...     ...  ...
# 15606  서울특별시 강남구 청담동     134  0134   0.0    래미안청담로이뷰  110.2000  202112   23
# 15607  서울특별시 강남구 청담동      10  0010   0.0   삼환아파트101동  114.9700  202112    8
# 15608  서울특별시 강남구 청담동  122-35  0122  35.0  청담신원아침도시마인   27.7131  202112   18
# 15609  서울특별시 강남구 청담동  134-38  0134  38.0        청담자이   89.3560  202112   27
# 15610  서울특별시 강남구 청담동  102-13  0102  13.0   청담파라곤Ⅱ2단지  149.7400  202112   20
#
# ...

# %%
sort_g = apt_g[['계약년월', '거래금액(만원)']]

# %%
sort_g
# Out:
#          계약년월  거래금액(만원)
# 39687  202101    245000
# 39688  202101    220000
# 39689  202101    220000
# 39690  202101    220000
# 39691  202101    145000
# ...       ...       ...
# 15606  202112    380000
# 15607  202112    198000
# 15608  202112     32000
# 15609  202112    362500
# 15610  202112    320000
#
# [2243 rows x 2 columns]

# %%
g_mean = sort_g.groupby('계약년월').mean() # groupby 해준 후 .mean이나 이런거 해주기

# %%
g_mean
# Out:
#              거래금액(만원)
# 계약년월
# 202101  199820.028125
# 202102  222719.726027
# 202103  207903.793103
# 202104  220931.512605
# 202105  188009.819608
# 202106  195719.893491
# 202107  207666.445498
# 202108  197057.090452
# 202109  209023.877551
# 202110  211094.744186
# 202111  218153.750000
# 202112  239370.000000

# %%
type(sort_g)
# Out:
# pandas.core.frame.DataFrame

# %%
sort_g[['거래금액(만원)']]
# Out:
#        거래금액(만원)
# 39687    245000
# 39688    220000
# 39689    220000
# 39690    220000
# 39691    145000
# ...         ...
# 15606    380000
# 15607    198000
# 15608     32000
# 15609    362500
# 15610    320000
#
# [2243 rows x 1 columns]

# %% [markdown]
# group_g = sort_g['거래금액(만원)'].groupby('계약년월').mean()

# %%
sort_g[['거래금액(만원)']].mean()
# Out:
# 거래금액(만원)    207165.843959
# dtype: float64

# %%
group_g

# %% [markdown]
# series에서 .values하면 껍데기를 벗겨내고 .tolist()하면 list로 바뀜

# %%
x = sort_g.iloc[:, 0].values

# %%
x
# Out:
# array([202101, 202101, 202101, ..., 202112, 202112, 202112], dtype=int64)

# %%
y = sort_g.iloc[:, 1].values

# %%
y
# Out:
# array(['245,000', '220,000', '220,000', ..., '32,000', '362,500',
#        '320,000'], dtype=object)

# %%
from matplotlib import font_manager, rc
import matplotlib.pyplot as plt

font_path='D:/20220103_lab/14.python/source/malgun.ttf'
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
plt.figure(figsize=(20,10))
plt.style.use('seaborn-pastel')
plt.title("강남구 아파트 최대 거래가격", fontsize=15) 
plt.xlabel("월")
plt.ylabel("가격")
plt.plot(g_mean)

plt.show()
