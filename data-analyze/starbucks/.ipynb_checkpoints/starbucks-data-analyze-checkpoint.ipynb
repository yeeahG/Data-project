# %% [markdown]
# ## Starbucks data analyze
# * 년, 월별 매장 오픈 개수를 분석하고 결과를 라인 차트로 나타냄

# %%
import requests
import matplotlib.pyplot as plt

# %%
url= 'https://www.starbucks.co.kr/store/getStore.do?r=804IUG79N7'
payload = {
    'in_biz_cds' : '0',
    'in_scodes' : '0',
    'ins_lat' : '37.5627128',
    'ins_lng' : '126.93279869999999',
    'search_text' : '',
    'p_sido_cd' : '01',
    'p_gugun_cd' : '',
    'in_distance' : '0',
    'in_biz_cd' : '',
    'isError' : 'true',
    'searchType' : 'C',
    'set_date' : '',
    'all_store' : '0',
    'T03' : '0',
    'T01' : '0',
    'T12' : '0',
    'T09' : '0',
    'T30' : '0',
    'T05' : '0',
    'T22' : '0',
    'T21' : '0',
    'T10' : '0',
    'T36' : '0',
    'P10' : '0',
    'P50' : '0',
    'P20' : '0',
    'P60' : '0',
    'P30' : '0',
    'P70' : '0',
    'P40' : '0',
    'P80' : '0',
    'whcroad_yn' : '0',
    'P90' : '0',
    'new_bool' : '0',
    'iend' : '1000',
    'rndCod' : 'V8UNZFKU44',}

# %%
r = requests.post(url, data=payload)
rt_dict = r.json()
rt_dict['list']
# Out:
# [{'seq': 0,
#   'sido_cd': None,
#   'sido_nm': None,
#   'gugun_cd': None,
#   'gugun_nm': None,
#   'code_order': None,
#   'view_yn': None,
#   'store_num': None,
#   'sido': None,
#   'gugun': None,
#   'address': None,
#   'new_img_nm': None,
#   'p_pro_seq': 0,
#   'p_view_yn': None,
#   'p_sido_cd': '',
#   'p_gugun_cd': '',
#   'p_store_nm': None,
#   'p_theme_cd': None,
#   'p_wireless_yn': None,
#   'p_smoking_yn': None,
#   'p_book_yn': None,
#   'p_music_yn': None,
#   'p_terrace_yn': None,
#   'p_table_yn': None,
#   'p_takeout_yn': None,
#   'p_parking_yn': None,
#   'p_dollar_assent': None,
#   'p_card_recharge': None,
#   'p_subway_yn': None,
#   'stb_store_file_renew': None,
#   'stb_store_theme_renew': None,
#   'stb_store_time_renew': None,
#   'stb_store_lsm': None,
#   's_code': '1509',
#   's_name': '역삼아레나빌딩',
#   'tel': '1522-3232',
#   'fax': '02-568-3763',
#   'sido_code': '01',
#   'sido_name': '서울',
#   'gugun_code': '0101',
#   'gugun_name': '강남구',
# ...

# %%
len(rt_dict['list'])
# 스타벅스의 전체 매장수
# Out:
# 577

# %%
type(rt_dict)
# Out:
# dict

# %% [markdown]
# ### 🔍스타벅스 매장이 많이 오픈 된 년, 달은 언제일까?

# %%
rt_dict['list'][0]['open_dt'][:-2]
# Out:
# '201906'

# %%
month_1 = []
month_2 = []

for i in range(1, len(rt_dict['list'])):
    month_1.append(rt_dict['list'][i]['open_dt'][:-2])
    for j in month_1:
        if j not in month_2:
            month_2.append(j)
#print(month_1)
print(month_2)
# Out:
# ['201811', '201912', '201907', '201902', '202005', '202004', '201808', '201806', '201803', '201708', '201705', '201703', '201608', '201612', '201606', '201611', '201509', '201605', '201602', '201504', '201412', '201408', '201407', '201402', '201311', '201403', '201310', '201306', '201307', '201309', '201304', '200408', '200305', '200301', '200203', '200111', '200103', '200712', '200805', '200503', '200504', '200505', '200604', '200602', '200812', '200508', '200412', '200411', '201202', '201201', '201111', '201107', '201106', '200912', '201203', '201008', '201003', '201007', '201211', '201108', '201109', '202101', '202109', '202011', '202107', '202106', '202104', '202010', '202112', '202108', '201610', '201508', '200410', '201204', '201909', '201807', '201712', '201709', '201503', '201502', '201312', '200308', '201209', '202103', '202203', '202102', '201905', '201802', '201607', '201308', '200903', '200902', '201910', '201901', '201809', '201501', '201404', '200703', '200909', '201205
# ...

# %%
month_starbucks = {}
for i in month_2:
    month_starbucks[i] = 0
print(month_starbucks)
# Out:
# {'201811': 0, '201912': 0, '201907': 0, '201902': 0, '202005': 0, '202004': 0, '201808': 0, '201806': 0, '201803': 0, '201708': 0, '201705': 0, '201703': 0, '201608': 0, '201612': 0, '201606': 0, '201611': 0, '201509': 0, '201605': 0, '201602': 0, '201504': 0, '201412': 0, '201408': 0, '201407': 0, '201402': 0, '201311': 0, '201403': 0, '201310': 0, '201306': 0, '201307': 0, '201309': 0, '201304': 0, '200408': 0, '200305': 0, '200301': 0, '200203': 0, '200111': 0, '200103': 0, '200712': 0, '200805': 0, '200503': 0, '200504': 0, '200505': 0, '200604': 0, '200602': 0, '200812': 0, '200508': 0, '200412': 0, '200411': 0, '201202': 0, '201201': 0, '201111': 0, '201107': 0, '201106': 0, '200912': 0, '201203': 0, '201008': 0, '201003': 0, '201007': 0, '201211': 0, '201108': 0, '201109': 0, '202101': 0, '202109': 0, '202011': 0, '202107': 0, '202106': 0, '202104': 0, '202010': 0, '202112': 0, '202108': 0, '201610': 0, '201508': 0, '200410': 0, '201204': 0, '201909': 0, '201807': 0, '201712':
# ...

# %%
for i in range(0,574) :
    for j in month_2:
        if j in rt_dict['list'][i]['open_dt'][-2]:
            month_starbucks[j] += 1
month_starbucks
# Out:
# {'201811': 5,
#  '201912': 3,
#  '201907': 1,
#  '201902': 3,
#  '202005': 3,
#  '202004': 4,
#  '201808': 5,
#  '201806': 5,
#  '201803': 6,
#  '201708': 6,
#  '201705': 9,
#  '201703': 8,
#  '201608': 3,
#  '201612': 9,
#  '201606': 4,
#  '201611': 3,
#  '201509': 3,
#  '201605': 6,
#  '201602': 3,
#  '201504': 4,
#  '201412': 5,
#  '201408': 1,
#  '201407': 4,
#  '201402': 4,
#  '201311': 1,
#  '201403': 5,
#  '201310': 4,
#  '201306': 3,
#  '201307': 4,
#  '201309': 4,
#  '201304': 1,
#  '200408': 1,
#  '200305': 1,
#  '200301': 1,
#  '200203': 2,
#  '200111': 1,
#  '200103': 1,
#  '200712': 1,
#  '200805': 2,
#  '200503': 3,
#  '200504': 1,
#  '200505': 2,
#  '200604': 2,
#  '200602': 2,
#  '200812': 2,
#  '200508': 2,
#  '200412': 1,
#  '200411': 1,
#  '201202': 5,
#  '201201': 4,
#  '201111': 2,
#  '201107': 3,
#  '201106': 6,
#  '200912': 4,
#  '201203': 2,
#  '201008': 2,
#  '201003': 1,
#  '201007': 5,
#  '201211': 2,
#  '201108': 3,
#  '201109': 2,
#  '202101': 4,
# ...

# %%
st_df = pd.DataFrame(month_starbucks, index=[0])

# %%
st_df
# Out:
#    201811  201912  201907  201902  202005  202004  201808  201806  201803  \
# 0       5       3       1       3       3       4       5       5       6
#
#    201708  ...  200310  200807  201102  201105  201812  200905  200406  \
# 0       6  ...       1       1       1       1       1       1       1
#
#    201701  200104  200701
# 0       3       1       1
#
# [1 rows x 205 columns]

# %%
st_sort=st_df.columns.tolist()

# %%
st_sort.sort()

# %%
st_df = st_df[st_sort]

# %%
st_df
# Out:
#    199907  200010  200103  200104  200108  200111  200112  200201  200202  \
# 0       1       1       1       1       1       1       2       1       1
#
#    200203  ...  202107  202108  202109  202110  202111  202112  202201  \
# 0       2  ...       5       5       5       1       3       2       3
#
#    202202  202203  202204
# 0       2       4       4
#
# [1 rows x 205 columns]

# %% [markdown]
# * chart 그리기

# %% [markdown]
# * 한글 font 지정

# %%
from matplotlib import font_manager, rc

font_path='D:/20220103_lab/14.python/source/malgun.ttf'
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
plt.figure(figsize=(20,5))
plt.style.use('seaborn-pastel')
plt.title("스타벅스 오픈 년월", fontsize=15) 
plt.xlabel("월")
plt.ylabel("오픈 수")
plt.plot(st_df.loc[0].index, st_df.loc[0].values)

plt.show()

# %% [markdown]
# ### 🔍스타벅스 매장이 많이 오픈 된 달은 언제일까?

# %%
rt_dict['list'][0]['open_dt'][4:-2]
# Out:
# '06'

# %%
st_m = []
st_m2= []

for x in range(1, len(rt_dict['list'])):
    st_m.append(rt_dict['list'][x]['open_dt'][4:-2])
    for y in st_m:
        if y not in st_m2:
            st_m2.append(y)
print(st_m2)
# Out:
# ['11', '12', '07', '02', '05', '04', '08', '06', '03', '09', '10', '01']

# %%
st_sort = {}
for x in st_m2:
    st_sort[x] = 0
print(st_sort)
# Out:
# {'11': 0, '12': 0, '07': 0, '02': 0, '05': 0, '04': 0, '08': 0, '06': 0, '03': 0, '09': 0, '10': 0, '01': 0}

# %%
for x in range(0,574) :
    for y in st_m2:
        if y in rt_dict['list'][x]['open_dt'][4:-2]:
            st_sort[y] += 1
st_sort
# Out:
# {'11': 37,
#  '12': 50,
#  '07': 48,
#  '02': 39,
#  '05': 48,
#  '04': 52,
#  '08': 47,
#  '06': 48,
#  '03': 62,
#  '09': 51,
#  '10': 47,
#  '01': 45}

# %%
st_sort_df = pd.DataFrame(st_sort, index=[0])

# %%
st_sort_df
# Out:
#    11  12  07  02  05  04  08  06  03  09  10  01
# 0  37  50  48  39  48  52  47  48  62  51  47  45

# %%
st_sort_df.iloc[:, 0]
# Out:
# 0    37
# Name: 11, dtype: int64

# %%
st_sort_df.iloc[0]
# Out:
# 11    37
# 12    50
# 07    48
# 02    39
# 05    48
# 04    52
# 08    47
# 06    48
# 03    62
# 09    51
# 10    47
# 01    45
# Name: 0, dtype: int64

# %%
st_sort_df.iloc[0].index
# Out:
# Index(['11', '12', '07', '02', '05', '04', '08', '06', '03', '09', '10', '01'], dtype='object')

# %%
st_sort_df.iloc[0].values
# Out:
# array([37, 50, 48, 39, 48, 52, 47, 48, 62, 51, 47, 45], dtype=int64)

# %%
from matplotlib import font_manager, rc

font_path='D:/20220103_lab/14.python/source/malgun.ttf'
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %%
plt.figure(figsize=(10,5))
plt.style.use('seaborn-pastel')
plt.title("스타벅스 오픈 달", fontsize=15) 
plt.xlabel("월")
plt.ylabel("오픈 수")
plt.plot(st_sort_df.iloc[0].index, st_sort_df.iloc[0].values)

plt.show()

# %%
month_1 = []
for x in range(1, len(rt_dict['list'])):
    a = rt_dict['list'][x]['open_dt'][:-2]
    month_1.append(a)
print(month_1)
# Out:
# ['201811', '201912', '201907', '201902', '202005', '202005', '202004', '201811', '201808', '201806', '201808', '201803', '201803', '201708', '201705', '201703', '201708', '201708', '201608', '201612', '201606', '201612', '201612', '201611', '201509', '201605', '201602', '201504', '201412', '201408', '201407', '201402', '201311', '201403', '201403', '201310', '201306', '201307', '201306', '201309', '201307', '201304', '200408', '200305', '200301', '200203', '200111', '200103', '200712', '200805', '200503', '200504', '200505', '200505', '200604', '200602', '201509', '200812', '200508', '200412', '200411', '201202', '201201', '201111', '201107', '201106', '200912', '201203', '200912', '201008', '201003', '201007', '201211', '201108', '201109', '202101', '202109', '202011', '202107', '202106', '202104', '202010', '202101', '202112', '202108', '202011', '201610', '201508', '201412', '200410', '201204', '202108', '201909', '202004', '201806', '201807', '201712', '201709', '201705', '201703
# ...

# %%
len(month_1)
# Out:
# 576

# %%
type(month_1)
# Out:
# list

# %%
import pandas as pd

# %%
month_df = pd.DataFrame(month_1)

# %%
type(month_df)
# Out:
# pandas.core.frame.DataFrame

# %%
month_df
# Out:
#           0
# 0    201811
# 1    201912
# 2    201907
# 3    201902
# 4    202005
# ..      ...
# 571  201503
# 572  201410
# 573  201203
# 574  202006
# 575  202012
#
# [576 rows x 1 columns]

# %%
month_df.value_counts()
# Out:
# 201705    9
# 201612    9
# 201801    8
# 201703    8
# 202104    7
#          ..
# 200711    1
# 200712    1
# 200801    1
# 200802    1
# 199907    1
# Length: 205, dtype: int64

# %%
type(month_df.value_counts())
# Out:
# pandas.core.series.Series

# %%
month_df.values
# Out:
# array([['201811'],
#        ['201912'],
#        ['201907'],
#        ['201902'],
#        ['202005'],
#        ['202005'],
#        ['202004'],
#        ['201811'],
#        ['201808'],
#        ['201806'],
#        ['201808'],
#        ['201803'],
#        ['201803'],
#        ['201708'],
#        ['201705'],
#        ['201703'],
#        ['201708'],
#        ['201708'],
#        ['201608'],
#        ['201612'],
#        ['201606'],
#        ['201612'],
#        ['201612'],
#        ['201611'],
#        ['201509'],
#        ['201605'],
#        ['201602'],
#        ['201504'],
#        ['201412'],
#        ['201408'],
#        ['201407'],
#        ['201402'],
#        ['201311'],
#        ['201403'],
#        ['201403'],
#        ['201310'],
#        ['201306'],
#        ['201307'],
#        ['201306'],
#        ['201309'],
#        ['201307'],
#        ['201304'],
#        ['200408'],
#        ['200305'],
#        ['200301'],
#        ['200203'],
#        ['200111'],
# ...

# %%
month_df.value_counts().sort_index()
# Out:
# 199907    1
# 200010    1
# 200103    1
# 200104    1
# 200108    1
#          ..
# 202112    2
# 202201    3
# 202202    2
# 202203    4
# 202204    4
# Length: 205, dtype: int64

# %%
final_st = month_df.value_counts().sort_index()

# %%
final_st.to_dict()
# Out:
# {('199907',): 1,
#  ('200010',): 1,
#  ('200103',): 1,
#  ('200104',): 1,
#  ('200108',): 1,
#  ('200111',): 1,
#  ('200112',): 2,
#  ('200201',): 1,
#  ('200202',): 1,
#  ('200203',): 2,
#  ('200204',): 1,
#  ('200206',): 1,
#  ('200208',): 1,
#  ('200209',): 1,
#  ('200301',): 1,
#  ('200305',): 1,
#  ('200307',): 1,
#  ('200308',): 2,
#  ('200309',): 1,
#  ('200310',): 1,
#  ('200312',): 1,
#  ('200402',): 1,
#  ('200403',): 2,
#  ('200406',): 1,
#  ('200407',): 1,
#  ('200408',): 1,
#  ('200410',): 2,
#  ('200411',): 1,
#  ('200412',): 1,
#  ('200503',): 3,
#  ('200504',): 1,
#  ('200505',): 2,
#  ('200506',): 1,
#  ('200507',): 1,
#  ('200508',): 2,
#  ('200510',): 3,
#  ('200601',): 1,
#  ('200602',): 2,
#  ('200604',): 2,
#  ('200605',): 2,
#  ('200607',): 1,
#  ('200611',): 1,
#  ('200701',): 1,
#  ('200703',): 2,
#  ('200704',): 1,
#  ('200706',): 2,
#  ('200707',): 1,
#  ('200709',): 1,
#  ('200710',): 2,
#  ('200711',): 1,
#  ('200712',): 1,
#  ('200801',): 1,
# ...

# %%
month_index = month_df.value_counts().sort_index()

# %%
month_index
# Out:
# 199907    1
# 200010    1
# 200103    1
# 200104    1
# 200108    1
#          ..
# 202112    2
# 202201    3
# 202202    2
# 202203    4
# 202204    4
# Length: 205, dtype: int64
